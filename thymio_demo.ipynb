# %%
import src.path_planning.path_planning as pp
from src.vision import camera
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Vision

# %%
# Open the default camera
print("Initializing camera...")
cam = camera.Camera(1)

print("Initializing map...")
cam.initialize_map(show=True)
map = cam.get_map()

# Get start and end positions
start = cam.get_robot_pose()[0]
goal = cam.get_goal_position()

cam.release()
cv2.destroyAllWindows()
# Out:
# Initializing camera...

# %%
plt.imshow(map)
plt.show()

# %% [markdown]
# ### Global navigation

# %%
# Plan the path
checkpoints = pp.get_checkpoints(map, start, goal)

# Visualize the result
pp.plot_grid_with_inflation_and_checkpoints(map, inflated_grid, checkpoints, path=path, start=start, goal=goal)
